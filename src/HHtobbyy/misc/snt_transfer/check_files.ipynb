# %%
import awkward as ak
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
fcp_dfd_sig24 = pd.read_parquet("/eos/uscms/store/group/lpcdihiggsboost/tsievert/HiggsDNA_parquet/DFDatasets/vManosv6/24_Manos_2026-04-20_12-49-04/Run3_2024/sim/GluGlutoHH_kl-1p00_kt-1p00_c2-0p00/nominal/NOTAG_preprocessed_test0.parquet")
fcp_preproc_sig24 = pd.read_parquet("/eos/uscms/store/group/lpcdihiggsboost/tsievert/HiggsDNA_parquet/preprocessed/v8/Run3_2024/sim/GluGlutoHH_kl-1p00_kt-1p00_c2-0p00/nominal/NOTAG_preprocessed.parquet")

# %%
fcp_dfd_sig24.head()
# Out:
#         eta  lead_eta  lead_phi  lead_mvaID  sublead_eta  sublead_phi  \
# 0  0.492834  0.973863 -0.399358   -0.138664    -0.069700    -1.074184
# 1 -1.298404 -1.967691  0.824803    0.089475    -1.234737     1.543527
# 2  0.831775  1.102667  0.352064   -0.701501     0.894138     1.211137
# 3 -0.353129  0.335077  0.419520    0.189101    -1.348481     1.215224
# 4  0.154130  0.341272  1.046932    0.115148    -0.186979     1.053388
#
#    sublead_mvaID  nonResReg_vbfpair_lead_bjet_eta  \
# 0       0.347193                        -0.397451
# 1       0.381872                        -0.431248
# 2       0.202129                         0.877833
# 3       0.244977                        -0.201059
# 4       0.409384                        -0.357806
#
#    nonResReg_vbfpair_lead_bjet_phi  nonResReg_vbfpair_lead_bjet_bTagWPL  \
# 0                         1.033224                             1.258086
# 1                        -0.769119                             1.258086
# ...

# %%
fcp_preproc_sig24.head()
# Out:
#    DeltaR_b1l1  DeltaR_b1l2  DeltaR_b2l1  DeltaR_b2l2  DeltaR_j10l1  \
# 0       -999.0       -999.0       -999.0       -999.0        -999.0
# 1       -999.0       -999.0       -999.0       -999.0        -999.0
# 2       -999.0       -999.0       -999.0       -999.0        -999.0
# 3       -999.0       -999.0       -999.0       -999.0        -999.0
# 4       -999.0       -999.0       -999.0       -999.0        -999.0
#
#    DeltaR_j10l2  DeltaR_j10l3  DeltaR_j10l4  DeltaR_j1l1  DeltaR_j1l2  \
# 0        -999.0        -999.0        -999.0       -999.0       -999.0
# 1        -999.0        -999.0        -999.0       -999.0       -999.0
# 2        -999.0        -999.0        -999.0       -999.0       -999.0
# 3        -999.0        -999.0        -999.0       -999.0       -999.0
# 4        -999.0        -999.0        -999.0       -999.0       -999.0
#
#    DeltaR_j1l3  DeltaR_j1l4  DeltaR_j2l1  DeltaR_j2l2  DeltaR_j2l3  \
# ...

# %%
print(f"preproc num mass window: {np.sum(fcp_preproc_sig24['mass'].gt(100).to_numpy(), fcp_preproc_sig24['mass'].lt(180).to_numpy())}")
