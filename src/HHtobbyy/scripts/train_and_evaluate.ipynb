# %%
# HEP packages
import eos_utils as eos

# Workspace packages
from HHtobbyy.event_discrimination.dataset import DFDataset
from HHtobbyy.event_discrimination.models import Model, map_model_to_Model
from HHtobbyy.workspace_utils.retrieval_utils import get_era_filepaths, get_input_filepaths

# %%
def main(dfdataset: DFDataset, model: Model, filepaths: list):
    # Building train DFDataset
    dfdataset.make_all_train(filepaths)

    # Training the model
    model.super().train_all_folds()

    # # Building test DFDataset
    # dfdataset.make_all_test(filepaths)

    # # Evaluating the model
    # predictions = model.super().evaluate_all_folds()

# %%
dfdataset_config = "/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/dataset/resolved_dataset_config.json"
model, model_config = "MLP", {"output_dirpath": "/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/Model_Outputs/MLP"}
eras = get_era_filepaths("/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/dataset/DFDataset_input_eras_2225.txt")

dfdataset = DFDataset(dfdataset_config)
model = map_model_to_Model(model)(dfdataset, model_config)

filepaths = get_input_filepaths(eras, dfdataset.class_sample_map, regex=f"*{dfdataset.filepostfix}")

main(dfdataset, model, filepaths)
# Out:
# cmslpcgpu3.fnal.gov      Mon Apr  6 11:35:47 2026  555.42.06
# [0] Tesla P100-PCIE-12GB | 41°C,   1 % |     0 / 12288 MB |
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 model, model_config = "MLP", {"output_dirpath": "/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/Model_Outputs/MLP"}
#       3 eras = get_era_filepaths("/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/dataset/DFDataset_input_eras_2225.txt")
#       4
#       5 dfdataset = DFDataset(dfdataset_config)
# ----> 6 model = map_model_to_Model(model)(dfdataset, model_config)
#       7
#       8 filepaths = get_input_filepaths(eras, dfdataset.class_sample_map, regex=f"*{dfdataset.filepostfix}")
#       9
#
# File /uscms_data/d3/tsievert/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/models/MLP/MLP.py:22, in MLP.__init__(self, dfdataset, config)
#      19 self.modelconfig = MLPConfig(self.dfdataset, config)
#      21 # Save config
# ---> 22 self.modelconfig.save_config()
#
# File /uscms_data/d3/tsievert/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/models/ModelConfig.py:35, in ModelConfig.save_config(self, filename)
#      33 def save_config(self, filename: str=config_filename):
#      34     assert filename.endswith('.json'), f"ERROR: Currently only supporting \'json\' type config serializations"
# ---> 35     eos.save_file_eos(self.__dict__, os.path.join(self.output_dirpath, filename))
#
# File /uscms_data/d3/tsievert/XHYbbgg/eos-utils/src/eos_utils/save_file_eos.py:15, in save_file_eos(object_, filepath, force)
#      13     subprocess.run(['rm', tmp_file])
#      14 else:
# ---> 15     save_file(object_, filepath)
#
# File /uscms_data/d3/tsievert/XHYbbgg/eos-utils/src/eos_utils/save_file_eos.py:18, in save_file(object_, filepath)
#      16 def save_file(object_: object, filepath: str):
#      17     if type(object_) is dict and filepath[filepath.rfind('.')+1:] == 'json':
# ---> 18         with open(filepath, 'w') as f: json.dump(object_, f)
#      19     elif type(object_) is pd.DataFrame and filepath[filepath.rfind('.')+1:] == 'parquet':
#      20         object_.to_parquet(filepath)
#
# File ~/nobackup/miniforge3/lib/python3.12/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/nobackup/miniforge3/lib/python3.12/json/encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File ~/nobackup/miniforge3/lib/python3.12/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~/nobackup/miniforge3/lib/python3.12/json/encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File ~/nobackup/miniforge3/lib/python3.12/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type DFDataset is not JSON serializable
