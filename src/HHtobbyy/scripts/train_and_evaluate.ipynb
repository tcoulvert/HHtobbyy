# %%
# HEP packages
import eos_utils as eos

# Workspace packages
from HHtobbyy.event_discrimination.dataset import DFDataset
from HHtobbyy.event_discrimination.models import Model, map_model_to_Model
from HHtobbyy.workspace_utils.retrieval_utils import get_era_filepaths, get_input_filepaths

# %%
def main(dfdataset: DFDataset, model: Model, filepaths: list):
    # Building train DFDataset
    dfdataset.make_all_train(filepaths)

    # # Training the model
    # model.super().train_all_folds()

    # # Building test DFDataset
    # dfdataset.make_all_test(filepaths)

    # # Evaluating the model
    # predictions = model.super().evaluate_all_folds()

# %%
dfdataset_config = "/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/dataset/resolved_dataset_config.json"
model, model_config = "MLP", {"output_dirpath": "/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/Model_Outputs/MLP"}
eras = get_era_filepaths("/uscms/home/tsievert/nobackup/XHYbbgg/HHtobbyy/src/HHtobbyy/event_discrimination/dataset/DFDataset_input_eras_2225.txt")

dfdataset = DFDataset(dfdataset_config)
model = map_model_to_Model(model)(dfdataset, model_config)

filepaths = get_input_filepaths(eras, dfdataset.class_sample_map, regex=f"*{dfdataset.filepostfix}")

# main(dfdataset, model, filepaths)
# Out:
# WARNING: Requested 2 appearance(s) of //, but search broke on 1 appearance. Returning -1
# WARNING: Requested 2 appearance(s) of //, but search broke on 1 appearance. Returning -1
# [ERROR] Server responded with an error: [3011] Unable to stat /store/group/lpcdihiggsboost/tsievert/HiggsDNA_parquet/DFDatasets/v0/dataset_config.json; No such file or directory
#
# Run: [ERROR] Server responded with an error: [3016] Unable to open - you specified a directory as target file name /store/group/lpcdihiggsboost/tsievert/HiggsDNA_parquet/DFDatasets/v0/dataset_config.json/; Is a directory (destination)
# cmslpcgpu3.fnal.gov      Mon Apr  6 15:36:36 2026  555.42.06
# [0] Tesla P100-PCIE-12GB | 41°C,   1 % |     0 / 12288 MB |
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4
#       5 dfdataset = DFDataset(dfdataset_config)
#       6 model = map_model_to_Model(model)(dfdataset, model_config)
#       7
# ----> 8 filepaths = get_input_filepaths(eras, dfdataset.class_sample_map, regex=f"*{dfdataset.filepostfix}")
#       9
#      10 # main(dfdataset, model, filepaths)
#
# File /uscms_data/d3/tsievert/XHYbbgg/HHtobbyy/src/HHtobbyy/workspace_utils/retrieval_utils.py:114, in get_input_filepaths(eras, class_sample_map, regex)
#     108         if match_sample(
#     109             sub_sample_filepath,
#     110             {glob_name for glob_names in class_sample_map.values() for glob_name in glob_names}
#     111         ) is not None:
#     112             input_filepaths.append(sample_filepath)
# --> 114 assert check_train_filepaths(input_filepaths, eras, class_sample_map), f"Train dataset is missing some samples for some eras."
#     116 return input_filepaths
#
# File /uscms_data/d3/tsievert/XHYbbgg/HHtobbyy/src/HHtobbyy/workspace_utils/retrieval_utils.py:86, in check_train_filepaths(train_filepaths, eras, class_sample_map)
#      84 good_dataset_bool = True
#      85 for glob_name in [glob_name for glob_names in class_sample_map.values() for glob_name in glob_names]:
# ---> 86     for era in get_era_filepaths(eras, split_data_mc_eras=True)[0]:
#      87         if 'data' in era: continue
#      88         if match_regex(f"{era}*{glob_name}", train_filepaths) is None:
#
# File /uscms_data/d3/tsievert/XHYbbgg/HHtobbyy/src/HHtobbyy/workspace_utils/retrieval_utils.py:70, in get_era_filepaths(input_eras, split_data_mc_eras)
#      68 def get_era_filepaths(input_eras: str, split_data_mc_eras: bool=False):
#      69     MC_eras, Data_eras = set(), set()
# ---> 70     with open(input_eras, 'r') as f:
#      71         for line in f:
#      72             stdline = line.strip()
#
# TypeError: expected str, bytes or os.PathLike object, not set
