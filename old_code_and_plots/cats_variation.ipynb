# %%
import numpy as np
import pandas as pd
import pickle
import mplhep as hep
import matplotlib.pyplot as plt
import yaml
import math
from tqdm import tqdm
plt.style.use(hep.style.CMS)
import uproot3 as uproot
import itertools
import os
import importlib.util
import sys
from array import array
import matplotlib.colors as mcolors
import gc

# %%
with open('2223Weighted/Nominal/Signal_2223.pkl', 'rb') as handle:
    Signal =  pd.read_pickle(handle)
with open('2223Weighted/Nominal/singleH_2223.pkl', 'rb') as handle:
    singleH =  pd.read_pickle(handle)
with open('2223Weighted/Nominal/vbfhh_2223.pkl', 'rb') as handle:
    VBFHH =  pd.read_pickle(handle)

# %%
Signal=Signal[[col for col in Signal.columns if col.startswith("weight")]+["2D_ttH_pred", "2D_BDT_pred" , "mass", "eventWeight"]]
singleH=singleH[[col for col in singleH.columns if col.startswith("weight")]+["2D_ttH_pred", "2D_BDT_pred" , "mass", "Type", "eventWeight"]]
VBFHH=VBFHH[[col for col in VBFHH.columns if col.startswith("weight")]+["2D_ttH_pred", "2D_BDT_pred" , "mass", "eventWeight"]]

# %%
with open('2223Weighted/Variation/Signal_2223_ScaleEBDown.pkl', 'rb') as handle:
    Signal_ScaleEBDown =  pd.read_pickle(handle) 
with open('2223Weighted/Variation/singleH_2223_ScaleEBDown.pkl', 'rb') as handle:
    singleH_ScaleEBDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_ScaleEBDown.pkl', 'rb') as handle:
    VBFHH_ScaleEBDown =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_ScaleEBUp.pkl', 'rb') as handle:
    Signal_ScaleEBUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_ScaleEBUp.pkl', 'rb') as handle:
    singleH_ScaleEBUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_ScaleEBUp.pkl', 'rb') as handle:
    VBFHH_ScaleEBUp =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_ScaleEEDown.pkl', 'rb') as handle:
    Signal_ScaleEEDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_ScaleEEDown.pkl', 'rb') as handle:
    singleH_ScaleEEDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_ScaleEEDown.pkl', 'rb') as handle:
    VBFHH_ScaleEEDown =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_ScaleEEUp.pkl', 'rb') as handle:
    Signal_ScaleEEUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_ScaleEEUp.pkl', 'rb') as handle:
    singleH_ScaleEEUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_ScaleEEUp.pkl', 'rb') as handle:
    VBFHH_ScaleEEUp =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_SmearingDown.pkl', 'rb') as handle:
    Signal_SmearingDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_SmearingDown.pkl', 'rb') as handle:
    singleH_SmearingDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_SmearingDown.pkl', 'rb') as handle:
    VBFHH_SmearingDown =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_SmearingUp.pkl', 'rb') as handle:
    Signal_SmearingUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_SmearingUp.pkl', 'rb') as handle:
    singleH_SmearingUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_SmearingUp.pkl', 'rb') as handle:
    VBFHH_SmearingUp =  pd.read_pickle(handle)

# %%
Variables=["2D_ttH_pred", "2D_BDT_pred" , "mass", "eventWeight", "weight"]
Variables_H=["2D_ttH_pred", "2D_BDT_pred" , "mass", "eventWeight", "weight", "Type"]

# %%
df_S= Signal
df_B= singleH
df_VBF = VBFHH 

df_S_EBDown= Signal_ScaleEBDown[Variables]
df_B_EBDown= singleH_ScaleEBDown[Variables_H]
df_VBF_EBDown = VBFHH_ScaleEBDown[Variables] 

df_S_EBUp= Signal_ScaleEBUp[Variables]
df_B_EBUp= singleH_ScaleEBUp[Variables_H]
df_VBF_EBUp = VBFHH_ScaleEBUp[Variables] 

df_S_EEDown= Signal_ScaleEEDown[Variables]
df_B_EEDown= singleH_ScaleEEDown[Variables_H]
df_VBF_EEDown = VBFHH_ScaleEEDown[Variables] 

df_S_EEUp= Signal_ScaleEEUp[Variables]
df_B_EEUp= singleH_ScaleEEUp[Variables_H]
df_VBF_EEUp = VBFHH_ScaleEEUp[Variables] 

df_S_SmearingDown= Signal_SmearingDown[Variables]
df_B_SmearingDown= singleH_SmearingDown[Variables_H]
df_VBF_SmearingDown = VBFHH_SmearingDown[Variables] 

df_S_SmearingUp= Signal_SmearingUp[Variables]
df_B_SmearingUp= singleH_SmearingUp[Variables_H]
df_VBF_SmearingUp = VBFHH_SmearingUp[Variables]

# %%
del Signal,singleH,VBFHH,Signal_ScaleEBDown,singleH_ScaleEBDown,VBFHH_ScaleEBDown,Signal_ScaleEBUp,
singleH_ScaleEBUp,VBFHH_ScaleEBUp, Signal_ScaleEEDown,singleH_ScaleEEDown,VBFHH_ScaleEEDown,Signal_ScaleEEUp,
singleH_ScaleEEUp,VBFHH_ScaleEEUp,Signal_SmearingDown,singleH_SmearingDown,VBFHH_SmearingDown,Signal_SmearingUp
singleH_SmearingUp,VBFHH_SmearingUp

gc.collect()
# Out:
# 0

# %%
with open('2223Weighted/Variation/Signal_2223_JECDown.pkl', 'rb') as handle:
    Signal_JECDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_JECDown.pkl', 'rb') as handle:
    singleH_JECDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_JECDown.pkl', 'rb') as handle:
    VBFHH_JECDown =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_JECUp.pkl', 'rb') as handle:
    Signal_JECUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_JECUp.pkl', 'rb') as handle:
    singleH_JECUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_JECUp.pkl', 'rb') as handle:
    VBFHH_JECUp =  pd.read_pickle(handle)

# %%
df_S_JECDown= Signal_JECDown[Variables]
df_B_JECDown= singleH_JECDown[Variables_H]
df_VBF_JECDown = VBFHH_JECDown[Variables] 

df_S_JECUp= Signal_JECUp[Variables]
df_B_JECUp= singleH_JECUp[Variables_H]
df_VBF_JECUp = VBFHH_JECUp[Variables]

# %%
del Signal_JECDown,singleH_JECDown,VBFHH_JECDown,Signal_JECUp,singleH_JECUp,VBFHH_JECUp 
gc.collect()
# Out:
# 0

# %%
with open('2223Weighted/Variation/Signal_2223_JERDown.pkl', 'rb') as handle:
    Signal_JERDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_JERDown.pkl', 'rb') as handle:
    singleH_JERDown =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_JERDown.pkl', 'rb') as handle:
    VBFHH_JERDown =  pd.read_pickle(handle)

# %%
with open('2223Weighted/Variation/Signal_2223_JERUp.pkl', 'rb') as handle:
    Signal_JERUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/singleH_2223_JERUp.pkl', 'rb') as handle:
    singleH_JERUp =  pd.read_pickle(handle)
with open('2223Weighted/Variation/VBFHH_2223_JERUp.pkl', 'rb') as handle:
    VBFHH_JERUp =  pd.read_pickle(handle)

# %%
# Signal["eventWeight"] = 1.75724*Signal["eventWeight"]
# Signal_ScaleEBDown["eventWeight"] = 1.75724*Signal_ScaleEBDown["eventWeight"]
# Signal_ScaleEBUp["eventWeight"] = 1.75724*Signal_ScaleEBUp["eventWeight"]

# Signal_ScaleEEDown["eventWeight"] = 1.75724*Signal_ScaleEEDown["eventWeight"]
# Signal_ScaleEEUp["eventWeight"]  = 1.75724*Signal_ScaleEEUp["eventWeight"]

# Signal_SmearingDown["eventWeight"] = 1.75724*Signal_SmearingDown["eventWeight"]
# Signal_SmearingUp["eventWeight"] = 1.75724*Signal_SmearingUp["eventWeight"]

# %%
df_S_JERDown= Signal_JERDown[Variables]
df_B_JERDown= singleH_JERDown[Variables_H]
df_VBF_JERDown = VBFHH_JERDown[Variables] 

df_S_JERUp= Signal_JERUp[Variables]
df_B_JERUp= singleH_JERUp[Variables_H]
df_VBF_JERUp = VBFHH_JERUp[Variables]

# %%
del Signal_JERDown,singleH_JERDown,VBFHH_JERDown,Signal_JERUp,singleH_JERUp,VBFHH_JERUp
gc.collect()
# Out:
# 0

# %%
df_S["CMS_hgg_mass"]=df_S["mass"].to_numpy()
df_B["CMS_hgg_mass"]=df_B["mass"].to_numpy()
df_VBF["CMS_hgg_mass"]=df_VBF["mass"].to_numpy()

df_S_EBDown["CMS_hgg_mass"] = df_S_EBDown["mass"].to_numpy()
df_B_EBDown["CMS_hgg_mass"] = df_B_EBDown["mass"].to_numpy()
df_VBF_EBDown["CMS_hgg_mass"] = df_VBF_EBDown["mass"]

df_S_EBUp["CMS_hgg_mass"]=df_S_EBUp["mass"].to_numpy()
df_B_EBUp["CMS_hgg_mass"]= df_B_EBUp["mass"].to_numpy()
df_VBF_EBUp["CMS_hgg_mass"] = df_VBF_EBUp["mass"].to_numpy()

df_S_EEDown["CMS_hgg_mass"]=df_S_EEDown["mass"].to_numpy()
df_B_EEDown["CMS_hgg_mass"]= df_B_EEDown["mass"].to_numpy()
df_VBF_EEDown["CMS_hgg_mass"]= df_VBF_EEDown["mass"].to_numpy()

df_S_EEUp["CMS_hgg_mass"]=df_S_EEUp["mass"].to_numpy()
df_B_EEUp["CMS_hgg_mass"]= df_B_EEUp["mass"].to_numpy()
df_VBF_EEUp["CMS_hgg_mass"]= df_VBF_EEUp["mass"].to_numpy()

df_S_SmearingDown["CMS_hgg_mass"]=df_S_SmearingDown["mass"].to_numpy()
df_B_SmearingDown["CMS_hgg_mass"]=df_B_SmearingDown["mass"].to_numpy()
df_VBF_SmearingDown["CMS_hgg_mass"]=df_VBF_SmearingDown["mass"].to_numpy()

df_S_SmearingUp["CMS_hgg_mass"]= df_S_SmearingUp["mass"].to_numpy()
df_B_SmearingUp["CMS_hgg_mass"]= df_B_SmearingUp["mass"].to_numpy()
df_VBF_SmearingUp["CMS_hgg_mass"]= df_VBF_SmearingUp["mass"].to_numpy()


df_S_JECDown["CMS_hgg_mass"]= df_S_JECDown["mass"].to_numpy()
df_B_JECDown["CMS_hgg_mass"]=df_B_JECDown["mass"].to_numpy()
df_VBF_JECDown["CMS_hgg_mass"] = df_VBF_JECDown["mass"].to_numpy()

df_S_JECUp["CMS_hgg_mass"]= df_S_JECUp["mass"].to_numpy()
df_B_JECUp["CMS_hgg_mass"]= df_B_JECUp["mass"].to_numpy()
df_VBF_JECUp["CMS_hgg_mass"] = df_VBF_JECUp["mass"].to_numpy()

df_S_JERDown["CMS_hgg_mass"]= df_S_JERDown["mass"].to_numpy()
df_B_JERDown["CMS_hgg_mass"]= df_B_JERDown["mass"].to_numpy()
df_VBF_JERDown["CMS_hgg_mass"] = df_VBF_JERDown["mass"].to_numpy() 

df_S_JERUp["CMS_hgg_mass"] = df_S_JERUp["mass"].to_numpy()
df_B_JERUp["CMS_hgg_mass"] =df_B_JERUp["mass"].to_numpy()
df_VBF_JERUp["CMS_hgg_mass"] = df_VBF_JERUp["mass"].to_numpy()
# Out:
# /tmp/ipykernel_58846/2224917627.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_B_EBUp["CMS_hgg_mass"]= df_B_EBUp["mass"].to_numpy()
# /tmp/ipykernel_58846/2224917627.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_VBF_EBUp["CMS_hgg_mass"] = df_VBF_EBUp["mass"].to_numpy()
# /tmp/ipykernel_58846/2224917627.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#GGH
htype = 8.0

# %%
cat1_H = df_B[(df_B["Type"]==htype)&(df_B["2D_ttH_pred"]>0.987)&(df_B["2D_BDT_pred"]>0.9982)&(df_B["2D_BDT_pred"]<=1)]
cat1_S = df_S[(df_S["2D_ttH_pred"]>0.987)&(df_S["2D_BDT_pred"]>0.9982)&(df_S["2D_BDT_pred"]<=1)]
cat1_VBF = df_VBF[(df_VBF["2D_ttH_pred"]>0.987)&(df_VBF["2D_BDT_pred"]>0.9982)&(df_VBF["2D_BDT_pred"]<=1)]

cat1_H_EBDown = df_B_EBDown[(df_B_EBDown["Type"]==htype)&(df_B_EBDown["2D_ttH_pred"]>0.987)&(df_B_EBDown["2D_BDT_pred"]>0.9982)&(df_B_EBDown["2D_BDT_pred"]<=1)]
cat1_S_EBDown = df_S_EBDown[(df_S_EBDown["2D_ttH_pred"]>0.987)&(df_S_EBDown["2D_BDT_pred"]>0.9982)&(df_S_EBDown["2D_BDT_pred"]<=1)]
cat1_VBF_EBDown = df_VBF_EBDown[(df_VBF_EBDown["2D_ttH_pred"]>0.987)&(df_VBF_EBDown["2D_BDT_pred"]>0.9982)&(df_VBF_EBDown["2D_BDT_pred"]<=1)]

cat1_H_EBUp = df_B_EBUp[(df_B_EBUp["Type"]==htype)&(df_B_EBUp["2D_ttH_pred"]>0.987)&(df_B_EBUp["2D_BDT_pred"]>0.9982)&(df_B_EBUp["2D_BDT_pred"]<=1)]
cat1_S_EBUp = df_S_EBUp[(df_S_EBUp["2D_ttH_pred"]>0.987)&(df_S_EBUp["2D_BDT_pred"]>0.9982)&(df_S_EBUp["2D_BDT_pred"]<=1)]
cat1_VBF_EBUp = df_VBF_EBUp[(df_VBF_EBUp["2D_ttH_pred"]>0.987)&(df_VBF_EBUp["2D_BDT_pred"]>0.9982)&(df_VBF_EBUp["2D_BDT_pred"]<=1)]

cat1_H_EEDown = df_B_EEDown[(df_B_EEDown["Type"]==htype)&(df_B_EEDown["2D_ttH_pred"]>0.987)&(df_B_EEDown["2D_BDT_pred"]>0.9982)&(df_B_EEDown["2D_BDT_pred"]<=1)]
cat1_S_EEDown = df_S_EEDown[(df_S_EEDown["2D_ttH_pred"]>0.987)&(df_S_EEDown["2D_BDT_pred"]>0.9982)&(df_S_EEDown["2D_BDT_pred"]<=1)]
cat1_VBF_EEDown = df_VBF_EEDown[(df_VBF_EEDown["2D_ttH_pred"]>0.987)&(df_VBF_EEDown["2D_BDT_pred"]>0.9982)&(df_VBF_EEDown["2D_BDT_pred"]<=1)]

cat1_H_EEUp = df_B_EEUp[(df_B_EEUp["Type"]==htype)&(df_B_EEUp["2D_ttH_pred"]>0.987)&(df_B_EEUp["2D_BDT_pred"]>0.9982)&(df_B_EEUp["2D_BDT_pred"]<=1)]
cat1_S_EEUp = df_S_EEUp[(df_S_EEUp["2D_ttH_pred"]>0.987)&(df_S_EEUp["2D_BDT_pred"]>0.9982)&(df_S_EEUp["2D_BDT_pred"]<=1)]
cat1_VBF_EEUp = df_VBF_EEUp[(df_VBF_EEUp["2D_ttH_pred"]>0.987)&(df_VBF_EEUp["2D_BDT_pred"]>0.9982)&(df_VBF_EEUp["2D_BDT_pred"]<=1)]

cat1_H_SmearingDown = df_B_SmearingDown[(df_B_SmearingDown["Type"]==htype)&(df_B_SmearingDown["2D_ttH_pred"]>0.987)&(df_B_SmearingDown["2D_BDT_pred"]>0.9982)&(df_B_SmearingDown["2D_BDT_pred"]<=1)]
cat1_S_SmearingDown = df_S_SmearingDown[(df_S_SmearingDown["2D_ttH_pred"]>0.987)&(df_S_SmearingDown["2D_BDT_pred"]>0.9982)&(df_S_SmearingDown["2D_BDT_pred"]<=1)]
cat1_VBF_SmearingDown = df_VBF_SmearingDown[(df_VBF_SmearingDown["2D_ttH_pred"]>0.987)&(df_VBF_SmearingDown["2D_BDT_pred"]>0.9982)&(df_VBF_SmearingDown["2D_BDT_pred"]<=1)]

cat1_H_SmearingUp = df_B_SmearingUp[(df_B_SmearingUp["Type"]==htype)&(df_B_SmearingUp["2D_ttH_pred"]>0.987)&(df_B_SmearingUp["2D_BDT_pred"]>0.9982)&(df_B_SmearingUp["2D_BDT_pred"]<=1)]
cat1_S_SmearingUp = df_S_SmearingUp[(df_S_SmearingUp["2D_ttH_pred"]>0.987)&(df_S_SmearingUp["2D_BDT_pred"]>0.9982)&(df_S_SmearingUp["2D_BDT_pred"]<=1)]
cat1_VBF_SmearingUp = df_VBF_SmearingUp[(df_VBF_SmearingUp["2D_ttH_pred"]>0.987)&(df_VBF_SmearingUp["2D_BDT_pred"]>0.9982)&(df_VBF_SmearingUp["2D_BDT_pred"]<=1)]

cat1_H_JECDown = df_B_JECDown[(df_B_JECDown["Type"]==htype)&(df_B_JECDown["2D_ttH_pred"]>0.987)&(df_B_JECDown["2D_BDT_pred"]>0.9982)&(df_B_JECDown["2D_BDT_pred"]<=1)]
cat1_S_JECDown = df_S_JECDown[(df_S_JECDown["2D_ttH_pred"]>0.987)&(df_S_JECDown["2D_BDT_pred"]>0.9982)&(df_S_JECDown["2D_BDT_pred"]<=1)]
cat1_VBF_JECDown = df_VBF_JECDown[(df_VBF_JECDown["2D_ttH_pred"]>0.987)&(df_VBF_JECDown["2D_BDT_pred"]>0.9982)&(df_VBF_JECDown["2D_BDT_pred"]<=1)]

cat1_H_JECUp = df_B_JECUp[(df_B_JECUp["Type"]==htype)&(df_B_JECUp["2D_ttH_pred"]>0.987)&(df_B_JECUp["2D_BDT_pred"]>0.9982)&(df_B_JECUp["2D_BDT_pred"]<=1)]
cat1_S_JECUp = df_S_JECUp[(df_S_JECUp["2D_ttH_pred"]>0.987)&(df_S_JECUp["2D_BDT_pred"]>0.9982)&(df_S_JECUp["2D_BDT_pred"]<=1)]
cat1_VBF_JECUp = df_VBF_JECUp[(df_VBF_JECUp["2D_ttH_pred"]>0.987)&(df_VBF_JECUp["2D_BDT_pred"]>0.9982)&(df_VBF_JECUp["2D_BDT_pred"]<=1)]

cat1_H_JERDown = df_B_JERDown[(df_B_JERDown["Type"]==htype)&(df_B_JERDown["2D_ttH_pred"]>0.987)&(df_B_JERDown["2D_BDT_pred"]>0.9982)&(df_B_JERDown["2D_BDT_pred"]<=1)]
cat1_S_JERDown = df_S_JERDown[(df_S_JERDown["2D_ttH_pred"]>0.987)&(df_S_JERDown["2D_BDT_pred"]>0.9982)&(df_S_JERDown["2D_BDT_pred"]<=1)]
cat1_VBF_JERDown = df_VBF_JERDown[(df_VBF_JERDown["2D_ttH_pred"]>0.987)&(df_VBF_JERDown["2D_BDT_pred"]>0.9982)&(df_VBF_JERDown["2D_BDT_pred"]<=1)]

cat1_H_JERUp = df_B_JERUp[(df_B_JERUp["Type"]==htype)&(df_B_JERUp["2D_ttH_pred"]>0.987)&(df_B_JERUp["2D_BDT_pred"]>0.9982)&(df_B_JERUp["2D_BDT_pred"]<=1)]
cat1_S_JERUp = df_S_JERUp[(df_S_JERUp["2D_ttH_pred"]>0.987)&(df_S_JERUp["2D_BDT_pred"]>0.9982)&(df_S_JERUp["2D_BDT_pred"]<=1)]
cat1_VBF_JERUp = df_VBF_JERUp[(df_VBF_JERUp["2D_ttH_pred"]>0.987)&(df_VBF_JERUp["2D_BDT_pred"]>0.9982)&(df_VBF_JERUp["2D_BDT_pred"]<=1)]

# %%
cat2_H = df_B[(df_B["Type"]==htype)&(df_B["2D_ttH_pred"]>0.92)&(df_B["2D_BDT_pred"]>0.994)&(df_B["2D_BDT_pred"]<=0.9982)]
cat2_S = df_S[(df_S["2D_ttH_pred"]>0.92)&(df_S["2D_BDT_pred"]>0.994)&(df_S["2D_BDT_pred"]<=0.9982)]
cat2_VBF = df_VBF[(df_VBF["2D_ttH_pred"]>0.92)&(df_VBF["2D_BDT_pred"]>0.994)&(df_VBF["2D_BDT_pred"]<=0.9982)]

cat2_H_EBDown = df_B_EBDown[(df_B_EBDown["Type"]==htype)&(df_B_EBDown["2D_ttH_pred"]>0.92)&(df_B_EBDown["2D_BDT_pred"]>0.994)&(df_B_EBDown["2D_BDT_pred"]<=0.9982)]
cat2_S_EBDown = df_S_EBDown[(df_S_EBDown["2D_ttH_pred"]>0.92)&(df_S_EBDown["2D_BDT_pred"]>0.994)&(df_S_EBDown["2D_BDT_pred"]<=0.9982)]
cat2_VBF_EBDown = df_VBF_EBDown[(df_VBF_EBDown["2D_ttH_pred"]>0.92)&(df_VBF_EBDown["2D_BDT_pred"]>0.994)&(df_VBF_EBDown["2D_BDT_pred"]<=0.9982)]

cat2_H_EBUp = df_B_EBUp[(df_B_EBUp["Type"]==htype)&(df_B_EBUp["2D_ttH_pred"]>0.92)&(df_B_EBUp["2D_BDT_pred"]>0.994)&(df_B_EBUp["2D_BDT_pred"]<=0.9982)]
cat2_S_EBUp = df_S_EBUp[(df_S_EBUp["2D_ttH_pred"]>0.92)&(df_S_EBUp["2D_BDT_pred"]>0.994)&(df_S_EBUp["2D_BDT_pred"]<=0.9982)]
cat2_VBF_EBUp = df_VBF_EBUp[(df_VBF_EBUp["2D_ttH_pred"]>0.92)&(df_VBF_EBUp["2D_BDT_pred"]>0.994)&(df_VBF_EBUp["2D_BDT_pred"]<=0.9982)]

cat2_H_EEDown = df_B_EEDown[(df_B_EEDown["Type"]==htype)&(df_B_EEDown["2D_ttH_pred"]>0.92)&(df_B_EEDown["2D_BDT_pred"]>0.994)&(df_B_EEDown["2D_BDT_pred"]<=0.9982)]
cat2_S_EEDown = df_S_EEDown[(df_S_EEDown["2D_ttH_pred"]>0.92)&(df_S_EEDown["2D_BDT_pred"]>0.994)&(df_S_EEDown["2D_BDT_pred"]<=0.9982)]
cat2_VBF_EEDown = df_VBF_EEDown[(df_VBF_EEDown["2D_ttH_pred"]>0.92)&(df_VBF_EEDown["2D_BDT_pred"]>0.994)&(df_VBF_EEDown["2D_BDT_pred"]<=0.9982)]

cat2_H_EEUp = df_B_EEUp[(df_B_EEUp["Type"]==htype)&(df_B_EEUp["2D_ttH_pred"]>0.92)&(df_B_EEUp["2D_BDT_pred"]>0.994)&(df_B_EEUp["2D_BDT_pred"]<=0.9982)]
cat2_S_EEUp = df_S_EEUp[(df_S_EEUp["2D_ttH_pred"]>0.92)&(df_S_EEUp["2D_BDT_pred"]>0.994)&(df_S_EEUp["2D_BDT_pred"]<=0.9982)]
cat2_VBF_EEUp = df_VBF_EEUp[(df_VBF_EEUp["2D_ttH_pred"]>0.92)&(df_VBF_EEUp["2D_BDT_pred"]>0.994)&(df_VBF_EEUp["2D_BDT_pred"]<=0.9982)]

cat2_H_SmearingDown = df_B_SmearingDown[(df_B_SmearingDown["Type"]==htype)&(df_B_SmearingDown["2D_ttH_pred"]>0.92)&(df_B_SmearingDown["2D_BDT_pred"]>0.994)&(df_B_SmearingDown["2D_BDT_pred"]<=0.9982)]
cat2_S_SmearingDown = df_S_SmearingDown[(df_S_SmearingDown["2D_ttH_pred"]>0.92)&(df_S_SmearingDown["2D_BDT_pred"]>0.994)&(df_S_SmearingDown["2D_BDT_pred"]<=0.9982)]
cat2_VBF_SmearingDown = df_VBF_SmearingDown[(df_VBF_SmearingDown["2D_ttH_pred"]>0.92)&(df_VBF_SmearingDown["2D_BDT_pred"]>0.994)&(df_VBF_SmearingDown["2D_BDT_pred"]<=0.9982)]

cat2_H_SmearingUp = df_B_SmearingUp[(df_B_SmearingUp["Type"]==htype)&(df_B_SmearingUp["2D_ttH_pred"]>0.92)&(df_B_SmearingUp["2D_BDT_pred"]>0.994)&(df_B_SmearingUp["2D_BDT_pred"]<=0.9982)]
cat2_S_SmearingUp = df_S_SmearingUp[(df_S_SmearingUp["2D_ttH_pred"]>0.92)&(df_S_SmearingUp["2D_BDT_pred"]>0.994)&(df_S_SmearingUp["2D_BDT_pred"]<=0.9982)]
cat2_VBF_SmearingUp = df_VBF_SmearingUp[(df_VBF_SmearingUp["2D_ttH_pred"]>0.92)&(df_VBF_SmearingUp["2D_BDT_pred"]>0.994)&(df_VBF_SmearingUp["2D_BDT_pred"]<=0.9982)]

cat2_H_JECDown = df_B_JECDown[(df_B_JECDown["Type"]==htype)&(df_B_JECDown["2D_ttH_pred"]>0.92)&(df_B_JECDown["2D_BDT_pred"]>0.994)&(df_B_JECDown["2D_BDT_pred"]<=0.9982)]
cat2_S_JECDown = df_S_JECDown[(df_S_JECDown["2D_ttH_pred"]>0.92)&(df_S_JECDown["2D_BDT_pred"]>0.994)&(df_S_JECDown["2D_BDT_pred"]<=0.9982)]
cat2_VBF_JECDown = df_VBF_JECDown[(df_VBF_JECDown["2D_ttH_pred"]>0.92)&(df_VBF_JECDown["2D_BDT_pred"]>0.994)&(df_VBF_JECDown["2D_BDT_pred"]<=0.9982)]

cat2_H_JECUp = df_B_JECUp[(df_B_JECUp["Type"]==htype)&(df_B_JECUp["2D_ttH_pred"]>0.92)&(df_B_JECUp["2D_BDT_pred"]>0.994)&(df_B_JECUp["2D_BDT_pred"]<=0.9982)]
cat2_S_JECUp = df_S_JECUp[(df_S_JECUp["2D_ttH_pred"]>0.92)&(df_S_JECUp["2D_BDT_pred"]>0.994)&(df_S_JECUp["2D_BDT_pred"]<=0.9982)]
cat2_VBF_JECUp = df_VBF_JECUp[(df_VBF_JECUp["2D_ttH_pred"]>0.92)&(df_VBF_JECUp["2D_BDT_pred"]>0.994)&(df_VBF_JECUp["2D_BDT_pred"]<=0.9982)]

cat2_H_JERDown = df_B_JERDown[(df_B_JERDown["Type"]==htype)&(df_B_JERDown["2D_ttH_pred"]>0.92)&(df_B_JERDown["2D_BDT_pred"]>0.994)&(df_B_JERDown["2D_BDT_pred"]<=0.9982)]
cat2_S_JERDown = df_S_JERDown[(df_S_JERDown["2D_ttH_pred"]>0.92)&(df_S_JERDown["2D_BDT_pred"]>0.994)&(df_S_JERDown["2D_BDT_pred"]<=0.9982)]
cat2_VBF_JERDown = df_VBF_JERDown[(df_VBF_JERDown["2D_ttH_pred"]>0.92)&(df_VBF_JERDown["2D_BDT_pred"]>0.994)&(df_VBF_JERDown["2D_BDT_pred"]<=0.9982)]

cat2_H_JERUp = df_B_JERUp[(df_B_JERUp["Type"]==htype)&(df_B_JERUp["2D_ttH_pred"]>0.92)&(df_B_JERUp["2D_BDT_pred"]>0.994)&(df_B_JERUp["2D_BDT_pred"]<=0.9982)]
cat2_S_JERUp = df_S_JERUp[(df_S_JERUp["2D_ttH_pred"]>0.92)&(df_S_JERUp["2D_BDT_pred"]>0.994)&(df_S_JERUp["2D_BDT_pred"]<=0.9982)]
cat2_VBF_JERUp = df_VBF_JERUp[(df_VBF_JERUp["2D_ttH_pred"]>0.92)&(df_VBF_JERUp["2D_BDT_pred"]>0.994)&(df_VBF_JERUp["2D_BDT_pred"]<=0.9982)]

# %%
cat3_H = df_B[(df_B["Type"]==htype)&(df_B["2D_ttH_pred"]>0.92)&(df_B["2D_BDT_pred"]>0.9864)&(df_B["2D_BDT_pred"]<=0.994)]
cat3_S = df_S[(df_S["2D_ttH_pred"]>0.92)&(df_S["2D_BDT_pred"]>0.9864)&(df_S["2D_BDT_pred"]<=0.994)]
cat3_VBF = df_VBF[(df_VBF["2D_ttH_pred"]>0.92)&(df_VBF["2D_BDT_pred"]>0.9864)&(df_VBF["2D_BDT_pred"]<=0.994)]

cat3_H_EBDown = df_B_EBDown[(df_B_EBDown["Type"]==htype)&(df_B_EBDown["2D_ttH_pred"]>0.92)&(df_B_EBDown["2D_BDT_pred"]>0.9864)&(df_B_EBDown["2D_BDT_pred"]<=0.994)]
cat3_S_EBDown = df_S_EBDown[(df_S_EBDown["2D_ttH_pred"]>0.92)&(df_S_EBDown["2D_BDT_pred"]>0.9864)&(df_S_EBDown["2D_BDT_pred"]<=0.994)]
cat3_VBF_EBDown = df_VBF_EBDown[(df_VBF_EBDown["2D_ttH_pred"]>0.92)&(df_VBF_EBDown["2D_BDT_pred"]>0.9864)&(df_VBF_EBDown["2D_BDT_pred"]<=0.994)]

cat3_H_EBUp = df_B_EBUp[(df_B_EBUp["Type"]==htype)&(df_B_EBUp["2D_ttH_pred"]>0.92)&(df_B_EBUp["2D_BDT_pred"]>0.9864)&(df_B_EBUp["2D_BDT_pred"]<=0.994)]
cat3_S_EBUp = df_S_EBUp[(df_S_EBUp["2D_ttH_pred"]>0.92)&(df_S_EBUp["2D_BDT_pred"]>0.9864)&(df_S_EBUp["2D_BDT_pred"]<=0.994)]
cat3_VBF_EBUp = df_VBF_EBUp[(df_VBF_EBUp["2D_ttH_pred"]>0.92)&(df_VBF_EBUp["2D_BDT_pred"]>0.9864)&(df_VBF_EBUp["2D_BDT_pred"]<=0.994)]

cat3_H_EEDown = df_B_EEDown[(df_B_EEDown["Type"]==htype)&(df_B_EEDown["2D_ttH_pred"]>0.92)&(df_B_EEDown["2D_BDT_pred"]>0.9864)&(df_B_EEDown["2D_BDT_pred"]<=0.994)]
cat3_S_EEDown = df_S_EEDown[(df_S_EEDown["2D_ttH_pred"]>0.92)&(df_S_EEDown["2D_BDT_pred"]>0.9864)&(df_S_EEDown["2D_BDT_pred"]<=0.994)]
cat3_VBF_EEDown = df_VBF_EEDown[(df_VBF_EEDown["2D_ttH_pred"]>0.92)&(df_VBF_EEDown["2D_BDT_pred"]>0.9864)&(df_VBF_EEDown["2D_BDT_pred"]<=0.994)]

cat3_H_EEUp = df_B_EEUp[(df_B_EEUp["Type"]==htype)&(df_B_EEUp["2D_ttH_pred"]>0.92)&(df_B_EEUp["2D_BDT_pred"]>0.9864)&(df_B_EEUp["2D_BDT_pred"]<=0.994)]
cat3_S_EEUp = df_S_EEUp[(df_S_EEUp["2D_ttH_pred"]>0.92)&(df_S_EEUp["2D_BDT_pred"]>0.9864)&(df_S_EEUp["2D_BDT_pred"]<=0.994)]
cat3_VBF_EEUp = df_VBF_EEUp[(df_VBF_EEUp["2D_ttH_pred"]>0.92)&(df_VBF_EEUp["2D_BDT_pred"]>0.9864)&(df_VBF_EEUp["2D_BDT_pred"]<=0.994)]

cat3_H_SmearingDown = df_B_SmearingDown[(df_B_SmearingDown["Type"]==htype)&(df_B_SmearingDown["2D_ttH_pred"]>0.92)&(df_B_SmearingDown["2D_BDT_pred"]>0.9864)&(df_B_SmearingDown["2D_BDT_pred"]<=0.994)]
cat3_S_SmearingDown = df_S_SmearingDown[(df_S_SmearingDown["2D_ttH_pred"]>0.92)&(df_S_SmearingDown["2D_BDT_pred"]>0.9864)&(df_S_SmearingDown["2D_BDT_pred"]<=0.994)]
cat3_VBF_SmearingDown = df_VBF_SmearingDown[(df_VBF_SmearingDown["2D_ttH_pred"]>0.92)&(df_VBF_SmearingDown["2D_BDT_pred"]>0.9864)&(df_VBF_SmearingDown["2D_BDT_pred"]<=0.994)]

cat3_H_SmearingUp = df_B_SmearingUp[(df_B_SmearingUp["Type"]==htype)&(df_B_SmearingUp["2D_ttH_pred"]>0.92)&(df_B_SmearingUp["2D_BDT_pred"]>0.9864)&(df_B_SmearingUp["2D_BDT_pred"]<=0.994)]
cat3_S_SmearingUp = df_S_SmearingUp[(df_S_SmearingUp["2D_ttH_pred"]>0.92)&(df_S_SmearingUp["2D_BDT_pred"]>0.9864)&(df_S_SmearingUp["2D_BDT_pred"]<=0.994)]
cat3_VBF_SmearingUp = df_VBF_SmearingUp[(df_VBF_SmearingUp["2D_ttH_pred"]>0.92)&(df_VBF_SmearingUp["2D_BDT_pred"]>0.9864)&(df_VBF_SmearingUp["2D_BDT_pred"]<=0.994)]

cat3_H_JECDown = df_B_JECDown[(df_B_JECDown["Type"]==htype)&(df_B_JECDown["2D_ttH_pred"]>0.92)&(df_B_JECDown["2D_BDT_pred"]>0.9864)&(df_B_JECDown["2D_BDT_pred"]<=0.994)]
cat3_S_JECDown = df_S_JECDown[(df_S_JECDown["2D_ttH_pred"]>0.92)&(df_S_JECDown["2D_BDT_pred"]>0.9864)&(df_S_JECDown["2D_BDT_pred"]<=0.994)]
cat3_VBF_JECDown = df_VBF_JECDown[(df_VBF_JECDown["2D_ttH_pred"]>0.92)&(df_VBF_JECDown["2D_BDT_pred"]>0.9864)&(df_VBF_JECDown["2D_BDT_pred"]<=0.994)]

cat3_H_JECUp = df_B_JECUp[(df_B_JECUp["Type"]==htype)&(df_B_JECUp["2D_ttH_pred"]>0.92)&(df_B_JECUp["2D_BDT_pred"]>0.9864)&(df_B_JECUp["2D_BDT_pred"]<=0.994)]
cat3_S_JECUp = df_S_JECUp[(df_S_JECUp["2D_ttH_pred"]>0.92)&(df_S_JECUp["2D_BDT_pred"]>0.9864)&(df_S_JECUp["2D_BDT_pred"]<=0.994)]
cat3_VBF_JECUp = df_VBF_JECUp[(df_VBF_JECUp["2D_ttH_pred"]>0.92)&(df_VBF_JECUp["2D_BDT_pred"]>0.9864)&(df_VBF_JECUp["2D_BDT_pred"]<=0.994)]

cat3_H_JERDown = df_B_JERDown[(df_B_JERDown["Type"]==htype)&(df_B_JERDown["2D_ttH_pred"]>0.92)&(df_B_JERDown["2D_BDT_pred"]>0.9864)&(df_B_JERDown["2D_BDT_pred"]<=0.994)]
cat3_S_JERDown = df_S_JERDown[(df_S_JERDown["2D_ttH_pred"]>0.92)&(df_S_JERDown["2D_BDT_pred"]>0.9864)&(df_S_JERDown["2D_BDT_pred"]<=0.994)]
cat3_VBF_JERDown = df_VBF_JERDown[(df_VBF_JERDown["2D_ttH_pred"]>0.92)&(df_VBF_JERDown["2D_BDT_pred"]>0.9864)&(df_VBF_JERDown["2D_BDT_pred"]<=0.994)]

cat3_H_JERUp = df_B_JERUp[(df_B_JERUp["Type"]==htype)&(df_B_JERUp["2D_ttH_pred"]>0.92)&(df_B_JERUp["2D_BDT_pred"]>0.9864)&(df_B_JERUp["2D_BDT_pred"]<=0.994)]
cat3_S_JERUp = df_S_JERUp[(df_S_JERUp["2D_ttH_pred"]>0.92)&(df_S_JERUp["2D_BDT_pred"]>0.9864)&(df_S_JERUp["2D_BDT_pred"]<=0.994)]
cat3_VBF_JERUp = df_VBF_JERUp[(df_VBF_JERUp["2D_ttH_pred"]>0.92)&(df_VBF_JERUp["2D_BDT_pred"]>0.9864)&(df_VBF_JERUp["2D_BDT_pred"]<=0.994)]

# %%
Tree_dic0={var:'float64' for var in cat1_H.columns}
Tree_value0={var:cat1_H[var].values for var in cat1_H.columns}
Tree_dic1={var:'float64' for var in cat2_H.columns}
Tree_value1={var:cat2_H[var].values for var in cat2_H.columns}
Tree_dic2={var:'float64' for var in cat3_H.columns}
Tree_value2={var:cat3_H[var].values for var in cat3_H.columns}

Tree_dic0_EBDown={var:'float64' for var in cat1_H_EBDown.columns}
Tree_value0_EBDown={var:cat1_H_EBDown[var].values for var in cat1_H_EBDown.columns}
Tree_dic1_EBDown={var:'float64' for var in cat2_H_EBDown.columns}
Tree_value1_EBDown={var:cat2_H_EBDown[var].values for var in cat2_H_EBDown.columns}
Tree_dic2_EBDown={var:'float64' for var in cat3_H_EBDown.columns}
Tree_value2_EBDown={var:cat3_H_EBDown[var].values for var in cat3_H_EBDown.columns}

Tree_dic0_EBUp={var:'float64' for var in cat1_H_EBUp.columns}
Tree_value0_EBUp={var:cat1_H_EBUp[var].values for var in cat1_H_EBUp.columns}
Tree_dic1_EBUp={var:'float64' for var in cat2_H_EBUp.columns}
Tree_value1_EBUp={var:cat2_H_EBUp[var].values for var in cat2_H_EBUp.columns}
Tree_dic2_EBUp={var:'float64' for var in cat3_H_EBUp.columns}
Tree_value2_EBUp={var:cat3_H_EBUp[var].values for var in cat3_H_EBUp.columns}

Tree_dic0_EEDown={var:'float64' for var in cat1_H_EEDown.columns}
Tree_value0_EEDown={var:cat1_H_EEDown[var].values for var in cat1_H_EEDown.columns}
Tree_dic1_EEDown={var:'float64' for var in cat2_H_EEDown.columns}
Tree_value1_EEDown={var:cat2_H_EEDown[var].values for var in cat2_H_EEDown.columns}
Tree_dic2_EEDown={var:'float64' for var in cat3_H_EEDown.columns}
Tree_value2_EEDown={var:cat3_H_EEDown[var].values for var in cat3_H_EEDown.columns}

Tree_dic0_EEUp={var:'float64' for var in cat1_H_EEUp.columns}
Tree_value0_EEUp={var:cat1_H_EEUp[var].values for var in cat1_H_EEUp.columns}
Tree_dic1_EEUp={var:'float64' for var in cat2_H_EEUp.columns}
Tree_value1_EEUp={var:cat2_H_EEUp[var].values for var in cat2_H_EEUp.columns}
Tree_dic2_EEUp={var:'float64' for var in cat3_H_EEUp.columns}
Tree_value2_EEUp={var:cat3_H_EEUp[var].values for var in cat3_H_EEUp.columns}

Tree_dic0_SmearingDown={var:'float64' for var in cat1_H_SmearingDown.columns}
Tree_value0_SmearingDown={var:cat1_H_SmearingDown[var].values for var in cat1_H_SmearingDown.columns}
Tree_dic1_SmearingDown={var:'float64' for var in cat2_H_SmearingDown.columns}
Tree_value1_SmearingDown={var:cat2_H_SmearingDown[var].values for var in cat2_H_SmearingDown.columns}
Tree_dic2_SmearingDown={var:'float64' for var in cat3_H_SmearingDown.columns}
Tree_value2_SmearingDown={var:cat3_H_SmearingDown[var].values for var in cat3_H_SmearingDown.columns}

Tree_dic0_SmearingUp={var:'float64' for var in cat1_H_SmearingUp.columns}
Tree_value0_SmearingUp={var:cat1_H_SmearingUp[var].values for var in cat1_H_SmearingUp.columns}
Tree_dic1_SmearingUp={var:'float64' for var in cat2_H_SmearingUp.columns}
Tree_value1_SmearingUp={var:cat2_H_SmearingUp[var].values for var in cat2_H_SmearingUp.columns}
Tree_dic2_SmearingUp={var:'float64' for var in cat3_H_SmearingUp.columns}
Tree_value2_SmearingUp={var:cat3_H_SmearingUp[var].values for var in cat3_H_SmearingUp.columns}

Tree_dic0_JECDown={var:'float64' for var in cat1_H_JECDown.columns}
Tree_value0_JECDown={var:cat1_H_JECDown[var].values for var in cat1_H_JECDown.columns}
Tree_dic1_JECDown={var:'float64' for var in cat2_H_JECDown.columns}
Tree_value1_JECDown={var:cat2_H_JECDown[var].values for var in cat2_H_JECDown.columns}
Tree_dic2_JECDown={var:'float64' for var in cat3_H_JECDown.columns}
Tree_value2_JECDown={var:cat3_H_JECDown[var].values for var in cat3_H_JECDown.columns}

Tree_dic0_JECUp={var:'float64' for var in cat1_H_JECUp.columns}
Tree_value0_JECUp={var:cat1_H_JECUp[var].values for var in cat1_H_JECUp.columns}
Tree_dic1_JECUp={var:'float64' for var in cat2_H_JECUp.columns}
Tree_value1_JECUp={var:cat2_H_JECUp[var].values for var in cat2_H_JECUp.columns}
Tree_dic2_JECUp={var:'float64' for var in cat3_H_JECUp.columns}
Tree_value2_JECUp={var:cat3_H_JECUp[var].values for var in cat3_H_JECUp.columns}

Tree_dic0_JERDown={var:'float64' for var in cat1_H_JERDown.columns}
Tree_value0_JERDown={var:cat1_H_JERDown[var].values for var in cat1_H_JERDown.columns}
Tree_dic1_JERDown={var:'float64' for var in cat2_H_JERDown.columns}
Tree_value1_JERDown={var:cat2_H_JERDown[var].values for var in cat2_H_JERDown.columns}
Tree_dic2_JERDown={var:'float64' for var in cat3_H_JERDown.columns}
Tree_value2_JERDown={var:cat3_H_JERDown[var].values for var in cat3_H_JERDown.columns}

Tree_dic0_JERUp={var:'float64' for var in cat1_H_JERUp.columns}
Tree_value0_JERUp={var:cat1_H_JERUp[var].values for var in cat1_H_JERUp.columns}
Tree_dic1_JERUp={var:'float64' for var in cat2_H_JERUp.columns}
Tree_value1_JERUp={var:cat2_H_JERUp[var].values for var in cat2_H_JERUp.columns}
Tree_dic2_JERUp={var:'float64' for var in cat3_H_JERUp.columns}
Tree_value2_JERUp={var:cat3_H_JERUp[var].values for var in cat3_H_JERUp.columns}

# %%
proc="bbh"

# %%
with uproot.recreate('2223Weighted/%s_0507.root'%proc) as file:
    file['%s_125_13p6TeV_cat0'%proc] = uproot.newtree(Tree_dic0)
    file['%s_125_13p6TeV_cat0'%proc].extend(Tree_value0)
    file['%s_125_13p6TeV_cat1'%proc] = uproot.newtree(Tree_dic1)
    file['%s_125_13p6TeV_cat1'%proc].extend(Tree_value1)
    file['%s_125_13p6TeV_cat2'%proc] = uproot.newtree(Tree_dic2)
    file['%s_125_13p6TeV_cat2'%proc].extend(Tree_value2)

    file['%s_125_13p6TeV_cat0_EBScaleDown01sigma'%proc] = uproot.newtree(Tree_dic0_EBDown)
    file['%s_125_13p6TeV_cat0_EBScaleDown01sigma'%proc].extend(Tree_value0_EBDown)
    file['%s_125_13p6TeV_cat1_EBScaleDown01sigma'%proc] = uproot.newtree(Tree_dic1_EBDown)
    file['%s_125_13p6TeV_cat1_EBScaleDown01sigma'%proc].extend(Tree_value1_EBDown)
    file['%s_125_13p6TeV_cat2_EBScaleDown01sigma'%proc] = uproot.newtree(Tree_dic2_EBDown)
    file['%s_125_13p6TeV_cat2_EBScaleDown01sigma'%proc].extend(Tree_value2_EBDown)

    file['%s_125_13p6TeV_cat0_EBScaleUp01sigma'%proc] = uproot.newtree(Tree_dic0_EBUp)
    file['%s_125_13p6TeV_cat0_EBScaleUp01sigma'%proc].extend(Tree_value0_EBUp)
    file['%s_125_13p6TeV_cat1_EBScaleUp01sigma'%proc] = uproot.newtree(Tree_dic1_EBUp)
    file['%s_125_13p6TeV_cat1_EBScaleUp01sigma'%proc].extend(Tree_value1_EBUp)
    file['%s_125_13p6TeV_cat2_EBScaleUp01sigma'%proc] = uproot.newtree(Tree_dic2_EBUp)
    file['%s_125_13p6TeV_cat2_EBScaleUp01sigma'%proc].extend(Tree_value2_EBUp)

    file['%s_125_13p6TeV_cat0_EEScaleDown01sigma'%proc] = uproot.newtree(Tree_dic0_EEDown)
    file['%s_125_13p6TeV_cat0_EEScaleDown01sigma'%proc].extend(Tree_value0_EEDown)
    file['%s_125_13p6TeV_cat1_EEScaleDown01sigma'%proc] = uproot.newtree(Tree_dic1_EEDown)
    file['%s_125_13p6TeV_cat1_EEScaleDown01sigma'%proc].extend(Tree_value1_EEDown)
    file['%s_125_13p6TeV_cat2_EEScaleDown01sigma'%proc] = uproot.newtree(Tree_dic2_EEDown)
    file['%s_125_13p6TeV_cat2_EEScaleDown01sigma'%proc].extend(Tree_value2_EEDown)

    file['%s_125_13p6TeV_cat0_EEScaleUp01sigma'%proc] = uproot.newtree(Tree_dic0_EEUp)
    file['%s_125_13p6TeV_cat0_EEScaleUp01sigma'%proc].extend(Tree_value0_EEUp)
    file['%s_125_13p6TeV_cat1_EEScaleUp01sigma'%proc] = uproot.newtree(Tree_dic1_EEUp)
    file['%s_125_13p6TeV_cat1_EEScaleUp01sigma'%proc].extend(Tree_value1_EEUp)
    file['%s_125_13p6TeV_cat2_EEScaleUp01sigma'%proc] = uproot.newtree(Tree_dic2_EEUp)
    file['%s_125_13p6TeV_cat2_EEScaleUp01sigma'%proc].extend(Tree_value2_EEUp)

    file['%s_125_13p6TeV_cat0_SmearingDown01sigma'%proc] = uproot.newtree(Tree_dic0_SmearingDown)
    file['%s_125_13p6TeV_cat0_SmearingDown01sigma'%proc].extend(Tree_value0_SmearingDown)
    file['%s_125_13p6TeV_cat1_SmearingDown01sigma'%proc] = uproot.newtree(Tree_dic1_SmearingDown)
    file['%s_125_13p6TeV_cat1_SmearingDown01sigma'%proc].extend(Tree_value1_SmearingDown)
    file['%s_125_13p6TeV_cat2_SmearingDown01sigma'%proc] = uproot.newtree(Tree_dic2_SmearingDown)
    file['%s_125_13p6TeV_cat2_SmearingDown01sigma'%proc].extend(Tree_value2_SmearingDown)

    file['%s_125_13p6TeV_cat0_SmearingUp01sigma'%proc] = uproot.newtree(Tree_dic0_SmearingUp)
    file['%s_125_13p6TeV_cat0_SmearingUp01sigma'%proc].extend(Tree_value0_SmearingUp)
    file['%s_125_13p6TeV_cat1_SmearingUp01sigma'%proc] = uproot.newtree(Tree_dic1_SmearingUp)
    file['%s_125_13p6TeV_cat1_SmearingUp01sigma'%proc].extend(Tree_value1_SmearingUp)
    file['%s_125_13p6TeV_cat2_SmearingUp01sigma'%proc] = uproot.newtree(Tree_dic2_SmearingUp)
    file['%s_125_13p6TeV_cat2_SmearingUp01sigma'%proc].extend(Tree_value2_SmearingUp)
    
    file['%s_125_13p6TeV_cat0_JECDown01sigma'%proc] = uproot.newtree(Tree_dic0_JECDown)
    file['%s_125_13p6TeV_cat0_JECDown01sigma'%proc].extend(Tree_value0_JECDown)
    file['%s_125_13p6TeV_cat1_JECDown01sigma'%proc] = uproot.newtree(Tree_dic1_JECDown)
    file['%s_125_13p6TeV_cat1_JECDown01sigma'%proc].extend(Tree_value1_JECDown)
    file['%s_125_13p6TeV_cat2_JECDown01sigma'%proc] = uproot.newtree(Tree_dic2_JECDown)
    file['%s_125_13p6TeV_cat2_JECDown01sigma'%proc].extend(Tree_value2_JECDown)

    file['%s_125_13p6TeV_cat0_JECUp01sigma'%proc] = uproot.newtree(Tree_dic0_JECUp)
    file['%s_125_13p6TeV_cat0_JECUp01sigma'%proc].extend(Tree_value0_JECUp)
    file['%s_125_13p6TeV_cat1_JECUp01sigma'%proc] = uproot.newtree(Tree_dic1_JECUp)
    file['%s_125_13p6TeV_cat1_JECUp01sigma'%proc].extend(Tree_value1_JECUp)
    file['%s_125_13p6TeV_cat2_JECUp01sigma'%proc] = uproot.newtree(Tree_dic2_JECUp)
    file['%s_125_13p6TeV_cat2_JECUp01sigma'%proc].extend(Tree_value2_JECUp)

    file['%s_125_13p6TeV_cat0_JERDown01sigma'%proc] = uproot.newtree(Tree_dic0_JERDown)
    file['%s_125_13p6TeV_cat0_JERDown01sigma'%proc].extend(Tree_value0_JERDown)
    file['%s_125_13p6TeV_cat1_JERDown01sigma'%proc] = uproot.newtree(Tree_dic1_JERDown)
    file['%s_125_13p6TeV_cat1_JERDown01sigma'%proc].extend(Tree_value1_JERDown)
    file['%s_125_13p6TeV_cat2_JERDown01sigma'%proc] = uproot.newtree(Tree_dic2_JERDown)
    file['%s_125_13p6TeV_cat2_JERDown01sigma'%proc].extend(Tree_value2_JERDown)

    file['%s_125_13p6TeV_cat0_JERUp01sigma'%proc] = uproot.newtree(Tree_dic0_JERUp)
    file['%s_125_13p6TeV_cat0_JERUp01sigma'%proc].extend(Tree_value0_JERUp)
    file['%s_125_13p6TeV_cat1_JERUp01sigma'%proc] = uproot.newtree(Tree_dic1_JERUp)
    file['%s_125_13p6TeV_cat1_JERUp01sigma'%proc].extend(Tree_value1_JERUp)
    file['%s_125_13p6TeV_cat2_JERUp01sigma'%proc] = uproot.newtree(Tree_dic2_JERUp)
    file['%s_125_13p6TeV_cat2_JERUp01sigma'%proc].extend(Tree_value2_JERUp)

# %%
Tree_dic0={var:'float64' for var in cat1_S.columns}
Tree_value0={var:cat1_S[var].values for var in cat1_S.columns}
Tree_dic1={var:'float64' for var in cat2_S.columns}
Tree_value1={var:cat2_S[var].values for var in cat2_S.columns}
Tree_dic2={var:'float64' for var in cat3_S.columns}
Tree_value2={var:cat3_S[var].values for var in cat3_S.columns}

Tree_dic0_EBDown={var:'float64' for var in cat1_S_EBDown.columns}
Tree_value0_EBDown={var:cat1_S_EBDown[var].values for var in cat1_S_EBDown.columns}
Tree_dic1_EBDown={var:'float64' for var in cat2_S_EBDown.columns}
Tree_value1_EBDown={var:cat2_S_EBDown[var].values for var in cat2_S_EBDown.columns}
Tree_dic2_EBDown={var:'float64' for var in cat3_S_EBDown.columns}
Tree_value2_EBDown={var:cat3_S_EBDown[var].values for var in cat3_S_EBDown.columns}

Tree_dic0_EBUp={var:'float64' for var in cat1_S_EBUp.columns}
Tree_value0_EBUp={var:cat1_S_EBUp[var].values for var in cat1_S_EBUp.columns}
Tree_dic1_EBUp={var:'float64' for var in cat2_S_EBUp.columns}
Tree_value1_EBUp={var:cat2_S_EBUp[var].values for var in cat2_S_EBUp.columns}
Tree_dic2_EBUp={var:'float64' for var in cat3_S_EBUp.columns}
Tree_value2_EBUp={var:cat3_S_EBUp[var].values for var in cat3_S_EBUp.columns}

Tree_dic0_EEDown={var:'float64' for var in cat1_S_EEDown.columns}
Tree_value0_EEDown={var:cat1_S_EEDown[var].values for var in cat1_S_EEDown.columns}
Tree_dic1_EEDown={var:'float64' for var in cat2_S_EEDown.columns}
Tree_value1_EEDown={var:cat2_S_EEDown[var].values for var in cat2_S_EEDown.columns}
Tree_dic2_EEDown={var:'float64' for var in cat3_S_EEDown.columns}
Tree_value2_EEDown={var:cat3_S_EEDown[var].values for var in cat3_S_EEDown.columns}

Tree_dic0_EEUp={var:'float64' for var in cat1_S_EEUp.columns}
Tree_value0_EEUp={var:cat1_S_EEUp[var].values for var in cat1_S_EEUp.columns}
Tree_dic1_EEUp={var:'float64' for var in cat2_S_EEUp.columns}
Tree_value1_EEUp={var:cat2_S_EEUp[var].values for var in cat2_S_EEUp.columns}
Tree_dic2_EEUp={var:'float64' for var in cat3_S_EEUp.columns}
Tree_value2_EEUp={var:cat3_S_EEUp[var].values for var in cat3_S_EEUp.columns}

Tree_dic0_SmearingDown={var:'float64' for var in cat1_S_SmearingDown.columns}
Tree_value0_SmearingDown={var:cat1_S_SmearingDown[var].values for var in cat1_S_SmearingDown.columns}
Tree_dic1_SmearingDown={var:'float64' for var in cat2_S_SmearingDown.columns}
Tree_value1_SmearingDown={var:cat2_S_SmearingDown[var].values for var in cat2_S_SmearingDown.columns}
Tree_dic2_SmearingDown={var:'float64' for var in cat3_S_SmearingDown.columns}
Tree_value2_SmearingDown={var:cat3_S_SmearingDown[var].values for var in cat3_S_SmearingDown.columns}

Tree_dic0_SmearingUp={var:'float64' for var in cat1_S_SmearingUp.columns}
Tree_value0_SmearingUp={var:cat1_S_SmearingUp[var].values for var in cat1_S_SmearingUp.columns}
Tree_dic1_SmearingUp={var:'float64' for var in cat2_S_SmearingUp.columns}
Tree_value1_SmearingUp={var:cat2_S_SmearingUp[var].values for var in cat2_S_SmearingUp.columns}
Tree_dic2_SmearingUp={var:'float64' for var in cat3_S_SmearingUp.columns}
Tree_value2_SmearingUp={var:cat3_S_SmearingUp[var].values for var in cat3_S_SmearingUp.columns}

Tree_dic0_JECDown={var:'float64' for var in cat1_S_JECDown.columns}
Tree_value0_JECDown={var:cat1_S_JECDown[var].values for var in cat1_S_JECDown.columns}
Tree_dic1_JECDown={var:'float64' for var in cat2_S_JECDown.columns}
Tree_value1_JECDown={var:cat2_S_JECDown[var].values for var in cat2_S_JECDown.columns}
Tree_dic2_JECDown={var:'float64' for var in cat3_S_JECDown.columns}
Tree_value2_JECDown={var:cat3_S_JECDown[var].values for var in cat3_S_JECDown.columns}

Tree_dic0_JECUp={var:'float64' for var in cat1_S_JECUp.columns}
Tree_value0_JECUp={var:cat1_S_JECUp[var].values for var in cat1_S_JECUp.columns}
Tree_dic1_JECUp={var:'float64' for var in cat2_S_JECUp.columns}
Tree_value1_JECUp={var:cat2_S_JECUp[var].values for var in cat2_S_JECUp.columns}
Tree_dic2_JECUp={var:'float64' for var in cat3_S_JECUp.columns}
Tree_value2_JECUp={var:cat3_S_JECUp[var].values for var in cat3_S_JECUp.columns}

Tree_dic0_JERDown={var:'float64' for var in cat1_S_JERDown.columns}
Tree_value0_JERDown={var:cat1_S_JERDown[var].values for var in cat1_S_JERDown.columns}
Tree_dic1_JERDown={var:'float64' for var in cat2_S_JERDown.columns}
Tree_value1_JERDown={var:cat2_S_JERDown[var].values for var in cat2_S_JERDown.columns}
Tree_dic2_JERDown={var:'float64' for var in cat3_S_JERDown.columns}
Tree_value2_JERDown={var:cat3_S_JERDown[var].values for var in cat3_S_JERDown.columns}

Tree_dic0_JERUp={var:'float64' for var in cat1_S_JERUp.columns}
Tree_value0_JERUp={var:cat1_S_JERUp[var].values for var in cat1_S_JERUp.columns}
Tree_dic1_JERUp={var:'float64' for var in cat2_S_JERUp.columns}
Tree_value1_JERUp={var:cat2_S_JERUp[var].values for var in cat2_S_JERUp.columns}
Tree_dic2_JERUp={var:'float64' for var in cat3_S_JERUp.columns}
Tree_value2_JERUp={var:cat3_S_JERUp[var].values for var in cat3_S_JERUp.columns}

# %%
with uproot.recreate('2223Weighted/Signal_0507.root') as file:
    file['gghh_125_13p6TeV_cat0'] = uproot.newtree(Tree_dic0)
    file['gghh_125_13p6TeV_cat0'].extend(Tree_value0)
    file['gghh_125_13p6TeV_cat1'] = uproot.newtree(Tree_dic1)
    file['gghh_125_13p6TeV_cat1'].extend(Tree_value1)
    file['gghh_125_13p6TeV_cat2'] = uproot.newtree(Tree_dic2)
    file['gghh_125_13p6TeV_cat2'].extend(Tree_value2)

    file['gghh_125_13p6TeV_cat0_EBScaleDown01sigma'] = uproot.newtree(Tree_dic0_EBDown)
    file['gghh_125_13p6TeV_cat0_EBScaleDown01sigma'].extend(Tree_value0_EBDown)
    file['gghh_125_13p6TeV_cat1_EBScaleDown01sigma'] = uproot.newtree(Tree_dic1_EBDown)
    file['gghh_125_13p6TeV_cat1_EBScaleDown01sigma'].extend(Tree_value1_EBDown)
    file['gghh_125_13p6TeV_cat2_EBScaleDown01sigma'] = uproot.newtree(Tree_dic2_EBDown)
    file['gghh_125_13p6TeV_cat2_EBScaleDown01sigma'].extend(Tree_value2_EBDown)

    file['gghh_125_13p6TeV_cat0_EBScaleUp01sigma'] = uproot.newtree(Tree_dic0_EBUp)
    file['gghh_125_13p6TeV_cat0_EBScaleUp01sigma'].extend(Tree_value0_EBUp)
    file['gghh_125_13p6TeV_cat1_EBScaleUp01sigma'] = uproot.newtree(Tree_dic1_EBUp)
    file['gghh_125_13p6TeV_cat1_EBScaleUp01sigma'].extend(Tree_value1_EBUp)
    file['gghh_125_13p6TeV_cat2_EBScaleUp01sigma'] = uproot.newtree(Tree_dic2_EBUp)
    file['gghh_125_13p6TeV_cat2_EBScaleUp01sigma'].extend(Tree_value2_EBUp)

    file['gghh_125_13p6TeV_cat0_EEScaleDown01sigma'] = uproot.newtree(Tree_dic0_EEDown)
    file['gghh_125_13p6TeV_cat0_EEScaleDown01sigma'].extend(Tree_value0_EEDown)
    file['gghh_125_13p6TeV_cat1_EEScaleDown01sigma'] = uproot.newtree(Tree_dic1_EEDown)
    file['gghh_125_13p6TeV_cat1_EEScaleDown01sigma'].extend(Tree_value1_EEDown)
    file['gghh_125_13p6TeV_cat2_EEScaleDown01sigma'] = uproot.newtree(Tree_dic2_EEDown)
    file['gghh_125_13p6TeV_cat2_EEScaleDown01sigma'].extend(Tree_value2_EEDown)

    file['gghh_125_13p6TeV_cat0_EEScaleUp01sigma'] = uproot.newtree(Tree_dic0_EEUp)
    file['gghh_125_13p6TeV_cat0_EEScaleUp01sigma'].extend(Tree_value0_EEUp)
    file['gghh_125_13p6TeV_cat1_EEScaleUp01sigma'] = uproot.newtree(Tree_dic1_EEUp)
    file['gghh_125_13p6TeV_cat1_EEScaleUp01sigma'].extend(Tree_value1_EEUp)
    file['gghh_125_13p6TeV_cat2_EEScaleUp01sigma'] = uproot.newtree(Tree_dic2_EEUp)
    file['gghh_125_13p6TeV_cat2_EEScaleUp01sigma'].extend(Tree_value2_EEUp)

    file['gghh_125_13p6TeV_cat0_SmearingDown01sigma'] = uproot.newtree(Tree_dic0_SmearingDown)
    file['gghh_125_13p6TeV_cat0_SmearingDown01sigma'].extend(Tree_value0_SmearingDown)
    file['gghh_125_13p6TeV_cat1_SmearingDown01sigma'] = uproot.newtree(Tree_dic1_SmearingDown)
    file['gghh_125_13p6TeV_cat1_SmearingDown01sigma'].extend(Tree_value1_SmearingDown)
    file['gghh_125_13p6TeV_cat2_SmearingDown01sigma'] = uproot.newtree(Tree_dic2_SmearingDown)
    file['gghh_125_13p6TeV_cat2_SmearingDown01sigma'].extend(Tree_value2_SmearingDown)

    file['gghh_125_13p6TeV_cat0_SmearingUp01sigma'] = uproot.newtree(Tree_dic0_SmearingUp)
    file['gghh_125_13p6TeV_cat0_SmearingUp01sigma'].extend(Tree_value0_SmearingUp)
    file['gghh_125_13p6TeV_cat1_SmearingUp01sigma'] = uproot.newtree(Tree_dic1_SmearingUp)
    file['gghh_125_13p6TeV_cat1_SmearingUp01sigma'].extend(Tree_value1_SmearingUp)
    file['gghh_125_13p6TeV_cat2_SmearingUp01sigma'] = uproot.newtree(Tree_dic2_SmearingUp)
    file['gghh_125_13p6TeV_cat2_SmearingUp01sigma'].extend(Tree_value2_SmearingUp)
     
    file['gghh_125_13p6TeV_cat0_JECDown01sigma'] = uproot.newtree(Tree_dic0_JECDown)
    file['gghh_125_13p6TeV_cat0_JECDown01sigma'].extend(Tree_value0_JECDown)
    file['gghh_125_13p6TeV_cat1_JECDown01sigma'] = uproot.newtree(Tree_dic1_JECDown)
    file['gghh_125_13p6TeV_cat1_JECDown01sigma'].extend(Tree_value1_JECDown)
    file['gghh_125_13p6TeV_cat2_JECDown01sigma'] = uproot.newtree(Tree_dic2_JECDown)
    file['gghh_125_13p6TeV_cat2_JECDown01sigma'].extend(Tree_value2_JECDown)

    file['gghh_125_13p6TeV_cat0_JECUp01sigma'] = uproot.newtree(Tree_dic0_JECUp)
    file['gghh_125_13p6TeV_cat0_JECUp01sigma'].extend(Tree_value0_JECUp)
    file['gghh_125_13p6TeV_cat1_JECUp01sigma'] = uproot.newtree(Tree_dic1_JECUp)
    file['gghh_125_13p6TeV_cat1_JECUp01sigma'].extend(Tree_value1_JECUp)
    file['gghh_125_13p6TeV_cat2_JECUp01sigma'] = uproot.newtree(Tree_dic2_JECUp)
    file['gghh_125_13p6TeV_cat2_JECUp01sigma'].extend(Tree_value2_JECUp)
 
    file['gghh_125_13p6TeV_cat0_JERDown01sigma'] = uproot.newtree(Tree_dic0_JERDown)
    file['gghh_125_13p6TeV_cat0_JERDown01sigma'].extend(Tree_value0_JERDown)
    file['gghh_125_13p6TeV_cat1_JERDown01sigma'] = uproot.newtree(Tree_dic1_JERDown)
    file['gghh_125_13p6TeV_cat1_JERDown01sigma'].extend(Tree_value1_JERDown)
    file['gghh_125_13p6TeV_cat2_JERDown01sigma'] = uproot.newtree(Tree_dic2_JERDown)
    file['gghh_125_13p6TeV_cat2_JERDown01sigma'].extend(Tree_value2_JERDown)

    file['gghh_125_13p6TeV_cat0_JERUp01sigma'] = uproot.newtree(Tree_dic0_JERUp)
    file['gghh_125_13p6TeV_cat0_JERUp01sigma'].extend(Tree_value0_JERUp)
    file['gghh_125_13p6TeV_cat1_JERUp01sigma'] = uproot.newtree(Tree_dic1_JERUp)
    file['gghh_125_13p6TeV_cat1_JERUp01sigma'].extend(Tree_value1_JERUp)
    file['gghh_125_13p6TeV_cat2_JERUp01sigma'] = uproot.newtree(Tree_dic2_JERUp)
    file['gghh_125_13p6TeV_cat2_JERUp01sigma'].extend(Tree_value2_JERUp)

# %%
Tree_dic0={var:'float64' for var in cat1_VBF.columns}
Tree_value0={var:cat1_VBF[var].values for var in cat1_VBF.columns}
Tree_dic1={var:'float64' for var in cat2_VBF.columns}
Tree_value1={var:cat2_VBF[var].values for var in cat2_VBF.columns}
Tree_dic2={var:'float64' for var in cat3_VBF.columns}
Tree_value2={var:cat3_VBF[var].values for var in cat3_VBF.columns}

Tree_dic0_EBDown={var:'float64' for var in cat1_VBF_EBDown.columns}
Tree_value0_EBDown={var:cat1_VBF_EBDown[var].values for var in cat1_VBF_EBDown.columns}
Tree_dic1_EBDown={var:'float64' for var in cat2_VBF_EBDown.columns}
Tree_value1_EBDown={var:cat2_VBF_EBDown[var].values for var in cat2_VBF_EBDown.columns}
Tree_dic2_EBDown={var:'float64' for var in cat3_VBF_EBDown.columns}
Tree_value2_EBDown={var:cat3_VBF_EBDown[var].values for var in cat3_VBF_EBDown.columns}

Tree_dic0_EBUp={var:'float64' for var in cat1_VBF_EBUp.columns}
Tree_value0_EBUp={var:cat1_VBF_EBUp[var].values for var in cat1_VBF_EBUp.columns}
Tree_dic1_EBUp={var:'float64' for var in cat2_VBF_EBUp.columns}
Tree_value1_EBUp={var:cat2_VBF_EBUp[var].values for var in cat2_VBF_EBUp.columns}
Tree_dic2_EBUp={var:'float64' for var in cat3_VBF_EBUp.columns}
Tree_value2_EBUp={var:cat3_VBF_EBUp[var].values for var in cat3_VBF_EBUp.columns}

Tree_dic0_EEDown={var:'float64' for var in cat1_VBF_EEDown.columns}
Tree_value0_EEDown={var:cat1_VBF_EEDown[var].values for var in cat1_VBF_EEDown.columns}
Tree_dic1_EEDown={var:'float64' for var in cat2_VBF_EEDown.columns}
Tree_value1_EEDown={var:cat2_VBF_EEDown[var].values for var in cat2_VBF_EEDown.columns}
Tree_dic2_EEDown={var:'float64' for var in cat3_VBF_EEDown.columns}
Tree_value2_EEDown={var:cat3_VBF_EEDown[var].values for var in cat3_VBF_EEDown.columns}

Tree_dic0_EEUp={var:'float64' for var in cat1_VBF_EEUp.columns}
Tree_value0_EEUp={var:cat1_VBF_EEUp[var].values for var in cat1_VBF_EEUp.columns}
Tree_dic1_EEUp={var:'float64' for var in cat2_VBF_EEUp.columns}
Tree_value1_EEUp={var:cat2_VBF_EEUp[var].values for var in cat2_VBF_EEUp.columns}
Tree_dic2_EEUp={var:'float64' for var in cat3_VBF_EEUp.columns}
Tree_value2_EEUp={var:cat3_VBF_EEUp[var].values for var in cat3_VBF_EEUp.columns}

Tree_dic0_SmearingDown={var:'float64' for var in cat1_VBF_SmearingDown.columns}
Tree_value0_SmearingDown={var:cat1_VBF_SmearingDown[var].values for var in cat1_VBF_SmearingDown.columns}
Tree_dic1_SmearingDown={var:'float64' for var in cat2_VBF_SmearingDown.columns}
Tree_value1_SmearingDown={var:cat2_VBF_SmearingDown[var].values for var in cat2_VBF_SmearingDown.columns}
Tree_dic2_SmearingDown={var:'float64' for var in cat3_VBF_SmearingDown.columns}
Tree_value2_SmearingDown={var:cat3_VBF_SmearingDown[var].values for var in cat3_VBF_SmearingDown.columns}

Tree_dic0_SmearingUp={var:'float64' for var in cat1_VBF_SmearingUp.columns}
Tree_value0_SmearingUp={var:cat1_VBF_SmearingUp[var].values for var in cat1_VBF_SmearingUp.columns}
Tree_dic1_SmearingUp={var:'float64' for var in cat2_VBF_SmearingUp.columns}
Tree_value1_SmearingUp={var:cat2_VBF_SmearingUp[var].values for var in cat2_VBF_SmearingUp.columns}
Tree_dic2_SmearingUp={var:'float64' for var in cat3_VBF_SmearingUp.columns}
Tree_value2_SmearingUp={var:cat3_VBF_SmearingUp[var].values for var in cat3_VBF_SmearingUp.columns}

Tree_dic0_JECDown={var:'float64' for var in cat1_VBF_JECDown.columns}
Tree_value0_JECDown={var:cat1_VBF_JECDown[var].values for var in cat1_VBF_JECDown.columns}
Tree_dic1_JECDown={var:'float64' for var in cat2_VBF_JECDown.columns}
Tree_value1_JECDown={var:cat2_VBF_JECDown[var].values for var in cat2_VBF_JECDown.columns}
Tree_dic2_JECDown={var:'float64' for var in cat3_VBF_JECDown.columns}
Tree_value2_JECDown={var:cat3_VBF_JECDown[var].values for var in cat3_VBF_JECDown.columns}

Tree_dic0_JECUp={var:'float64' for var in cat1_VBF_JECUp.columns}
Tree_value0_JECUp={var:cat1_VBF_JECUp[var].values for var in cat1_VBF_JECUp.columns}
Tree_dic1_JECUp={var:'float64' for var in cat2_VBF_JECUp.columns}
Tree_value1_JECUp={var:cat2_VBF_JECUp[var].values for var in cat2_VBF_JECUp.columns}
Tree_dic2_JECUp={var:'float64' for var in cat3_VBF_JECUp.columns}
Tree_value2_JECUp={var:cat3_VBF_JECUp[var].values for var in cat3_VBF_JECUp.columns}

Tree_dic0_JERDown={var:'float64' for var in cat1_VBF_JERDown.columns}
Tree_value0_JERDown={var:cat1_VBF_JERDown[var].values for var in cat1_VBF_JERDown.columns}
Tree_dic1_JERDown={var:'float64' for var in cat2_VBF_JERDown.columns}
Tree_value1_JERDown={var:cat2_VBF_JERDown[var].values for var in cat2_VBF_JERDown.columns}
Tree_dic2_JERDown={var:'float64' for var in cat3_VBF_JERDown.columns}
Tree_value2_JERDown={var:cat3_VBF_JERDown[var].values for var in cat3_VBF_JERDown.columns}

Tree_dic0_JERUp={var:'float64' for var in cat1_VBF_JERUp.columns}
Tree_value0_JERUp={var:cat1_VBF_JERUp[var].values for var in cat1_VBF_JERUp.columns}
Tree_dic1_JERUp={var:'float64' for var in cat2_VBF_JERUp.columns}
Tree_value1_JERUp={var:cat2_VBF_JERUp[var].values for var in cat2_VBF_JERUp.columns}
Tree_dic2_JERUp={var:'float64' for var in cat3_VBF_JERUp.columns}
Tree_value2_JERUp={var:cat3_VBF_JERUp[var].values for var in cat3_VBF_JERUp.columns}

# %%
proc="vbfhh"

# %%
with uproot.recreate('2223Weighted/%s_0505.root'%proc) as file:
    file['%s_125_13p6TeV_cat0'%proc] = uproot.newtree(Tree_dic0)
    file['%s_125_13p6TeV_cat0'%proc].extend(Tree_value0)
    file['%s_125_13p6TeV_cat1'%proc] = uproot.newtree(Tree_dic1)
    file['%s_125_13p6TeV_cat1'%proc].extend(Tree_value1)
    file['%s_125_13p6TeV_cat2'%proc] = uproot.newtree(Tree_dic2)
    file['%s_125_13p6TeV_cat2'%proc].extend(Tree_value2)

    file['%s_125_13p6TeV_cat0_EBScaleDown01sigma'%proc] = uproot.newtree(Tree_dic0_EBDown)
    file['%s_125_13p6TeV_cat0_EBScaleDown01sigma'%proc].extend(Tree_value0_EBDown)
    file['%s_125_13p6TeV_cat1_EBScaleDown01sigma'%proc] = uproot.newtree(Tree_dic1_EBDown)
    file['%s_125_13p6TeV_cat1_EBScaleDown01sigma'%proc].extend(Tree_value1_EBDown)
    file['%s_125_13p6TeV_cat2_EBScaleDown01sigma'%proc] = uproot.newtree(Tree_dic2_EBDown)
    file['%s_125_13p6TeV_cat2_EBScaleDown01sigma'%proc].extend(Tree_value2_EBDown)

    file['%s_125_13p6TeV_cat0_EBScaleUp01sigma'%proc] = uproot.newtree(Tree_dic0_EBUp)
    file['%s_125_13p6TeV_cat0_EBScaleUp01sigma'%proc].extend(Tree_value0_EBUp)
    file['%s_125_13p6TeV_cat1_EBScaleUp01sigma'%proc] = uproot.newtree(Tree_dic1_EBUp)
    file['%s_125_13p6TeV_cat1_EBScaleUp01sigma'%proc].extend(Tree_value1_EBUp)
    file['%s_125_13p6TeV_cat2_EBScaleUp01sigma'%proc] = uproot.newtree(Tree_dic2_EBUp)
    file['%s_125_13p6TeV_cat2_EBScaleUp01sigma'%proc].extend(Tree_value2_EBUp)

    file['%s_125_13p6TeV_cat0_EEScaleDown01sigma'%proc] = uproot.newtree(Tree_dic0_EEDown)
    file['%s_125_13p6TeV_cat0_EEScaleDown01sigma'%proc].extend(Tree_value0_EEDown)
    file['%s_125_13p6TeV_cat1_EEScaleDown01sigma'%proc] = uproot.newtree(Tree_dic1_EEDown)
    file['%s_125_13p6TeV_cat1_EEScaleDown01sigma'%proc].extend(Tree_value1_EEDown)
    file['%s_125_13p6TeV_cat2_EEScaleDown01sigma'%proc] = uproot.newtree(Tree_dic2_EEDown)
    file['%s_125_13p6TeV_cat2_EEScaleDown01sigma'%proc].extend(Tree_value2_EEDown)

    file['%s_125_13p6TeV_cat0_EEScaleUp01sigma'%proc] = uproot.newtree(Tree_dic0_EEUp)
    file['%s_125_13p6TeV_cat0_EEScaleUp01sigma'%proc].extend(Tree_value0_EEUp)
    file['%s_125_13p6TeV_cat1_EEScaleUp01sigma'%proc] = uproot.newtree(Tree_dic1_EEUp)
    file['%s_125_13p6TeV_cat1_EEScaleUp01sigma'%proc].extend(Tree_value1_EEUp)
    file['%s_125_13p6TeV_cat2_EEScaleUp01sigma'%proc] = uproot.newtree(Tree_dic2_EEUp)
    file['%s_125_13p6TeV_cat2_EEScaleUp01sigma'%proc].extend(Tree_value2_EEUp)

    file['%s_125_13p6TeV_cat0_SmearingDown01sigma'%proc] = uproot.newtree(Tree_dic0_SmearingDown)
    file['%s_125_13p6TeV_cat0_SmearingDown01sigma'%proc].extend(Tree_value0_SmearingDown)
    file['%s_125_13p6TeV_cat1_SmearingDown01sigma'%proc] = uproot.newtree(Tree_dic1_SmearingDown)
    file['%s_125_13p6TeV_cat1_SmearingDown01sigma'%proc].extend(Tree_value1_SmearingDown)
    file['%s_125_13p6TeV_cat2_SmearingDown01sigma'%proc] = uproot.newtree(Tree_dic2_SmearingDown)
    file['%s_125_13p6TeV_cat2_SmearingDown01sigma'%proc].extend(Tree_value2_SmearingDown)

    file['%s_125_13p6TeV_cat0_SmearingUp01sigma'%proc] = uproot.newtree(Tree_dic0_SmearingUp)
    file['%s_125_13p6TeV_cat0_SmearingUp01sigma'%proc].extend(Tree_value0_SmearingUp)
    file['%s_125_13p6TeV_cat1_SmearingUp01sigma'%proc] = uproot.newtree(Tree_dic1_SmearingUp)
    file['%s_125_13p6TeV_cat1_SmearingUp01sigma'%proc].extend(Tree_value1_SmearingUp)
    file['%s_125_13p6TeV_cat2_SmearingUp01sigma'%proc] = uproot.newtree(Tree_dic2_SmearingUp)
    file['%s_125_13p6TeV_cat2_SmearingUp01sigma'%proc].extend(Tree_value2_SmearingUp)
    
    file['%s_125_13p6TeV_cat0_JECDown01sigma'%proc] = uproot.newtree(Tree_dic0_JECDown)
    file['%s_125_13p6TeV_cat0_JECDown01sigma'%proc].extend(Tree_value0_JECDown)
    file['%s_125_13p6TeV_cat1_JECDown01sigma'%proc] = uproot.newtree(Tree_dic1_JECDown)
    file['%s_125_13p6TeV_cat1_JECDown01sigma'%proc].extend(Tree_value1_JECDown)
    file['%s_125_13p6TeV_cat2_JECDown01sigma'%proc] = uproot.newtree(Tree_dic2_JECDown)
    file['%s_125_13p6TeV_cat2_JECDown01sigma'%proc].extend(Tree_value2_JECDown)

    file['%s_125_13p6TeV_cat0_JECUp01sigma'%proc] = uproot.newtree(Tree_dic0_JECUp)
    file['%s_125_13p6TeV_cat0_JECUp01sigma'%proc].extend(Tree_value0_JECUp)
    file['%s_125_13p6TeV_cat1_JECUp01sigma'%proc] = uproot.newtree(Tree_dic1_JECUp)
    file['%s_125_13p6TeV_cat1_JECUp01sigma'%proc].extend(Tree_value1_JECUp)
    file['%s_125_13p6TeV_cat2_JECUp01sigma'%proc] = uproot.newtree(Tree_dic2_JECUp)
    file['%s_125_13p6TeV_cat2_JECUp01sigma'%proc].extend(Tree_value2_JECUp)

    file['%s_125_13p6TeV_cat0_JERDown01sigma'%proc] = uproot.newtree(Tree_dic0_JERDown)
    file['%s_125_13p6TeV_cat0_JERDown01sigma'%proc].extend(Tree_value0_JERDown)
    file['%s_125_13p6TeV_cat1_JERDown01sigma'%proc] = uproot.newtree(Tree_dic1_JERDown)
    file['%s_125_13p6TeV_cat1_JERDown01sigma'%proc].extend(Tree_value1_JERDown)
    file['%s_125_13p6TeV_cat2_JERDown01sigma'%proc] = uproot.newtree(Tree_dic2_JERDown)
    file['%s_125_13p6TeV_cat2_JERDown01sigma'%proc].extend(Tree_value2_JERDown)

    file['%s_125_13p6TeV_cat0_JERUp01sigma'%proc] = uproot.newtree(Tree_dic0_JERUp)
    file['%s_125_13p6TeV_cat0_JERUp01sigma'%proc].extend(Tree_value0_JERUp)
    file['%s_125_13p6TeV_cat1_JERUp01sigma'%proc] = uproot.newtree(Tree_dic1_JERUp)
    file['%s_125_13p6TeV_cat1_JERUp01sigma'%proc].extend(Tree_value1_JERUp)
    file['%s_125_13p6TeV_cat2_JERUp01sigma'%proc] = uproot.newtree(Tree_dic2_JERUp)
    file['%s_125_13p6TeV_cat2_JERUp01sigma'%proc].extend(Tree_value2_JERUp)
